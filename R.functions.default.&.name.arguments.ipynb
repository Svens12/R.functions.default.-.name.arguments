# %%
mysum=function(x,y) {
    z=x+y
    return (z)
}

# %%
mysum=function(x,y,w) {
    z=x+y+w
    return (z)
}

# %%
mysum(4,5,7)
# Out:
# [1] 16

# %%
mysum(y=4,x=5,w=7)
# Out:
# [1] 16

# %%
mysum(y=4,w=5,7)
# Out:
# [1] 16

# %%
mysum=function(x,y=2,w=5) {
    z=x+y+w
    return (z)
}

# %%
mysum(2,4,5)
# Out:
# [1] 11

# %%
mysum(2)
# Out:
# [1] 9

# %%
mysum(3,4)
# Out:
# [1] 12

# %%
mysum=function(x=1,y=2,w=5) {
    z=x+y+w
    return (z)
}

# %%
mysum()
# Out:
# [1] 8

# %%
mysum=function(x,y=3,w=5) {
    z=x+y+w
    return (z)
}

# %%
mysum(3)
# Out:
# [1] 11

# %%
mysum=function(y,x=2,w=5) {
    z=x+y+w
    return (z)
}

# %%
mysum(3)
# Out:
# [1] 10
